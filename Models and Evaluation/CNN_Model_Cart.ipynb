# %% [markdown]
# <a href="https://colab.research.google.com/github/colinjhorgan/MLTSAFinalProject/blob/main/Models%20and%20Evaluation/CNN_Model_Cart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import pylab as plt
# %pylab inline

from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import KFold

from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Flatten, MaxPool2D

import seaborn as sns

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# Mounted at /content/gdrive

# %%
#Read in data and data labels
im_arr = np.load('/content/gdrive/MyDrive/3. MSDS Courses/Machine Learning Time Series/MLTSA22 Project/Data/image_arrayminmax.npy')
im_labs = np.load('/content/gdrive/MyDrive/3. MSDS Courses/Machine Learning Time Series/MLTSA22 Project/Data/image_labels.npy')

# %%
#Confirm read-in
print(im_arr.shape)
print(im_labs.shape)
# Out:
# (485, 300, 100, 3)
# (485,)

# %%
#Define input shape
input_shape = (300, 100, 3)
num_classes = np.unique(im_labs).shape[0]

# %%
#Define Training and Testing Data
X = im_arr
y = pd.Categorical(im_labs).codes

# %%
#Define optimizer
opt = keras.optimizers.Adam(learning_rate=1e-4)

# %%
#5-fold Cross Validation
np.random.seed(10)
seeds = np.random.randint(0, 1000, 5)
scores = []

for i in range(0, 5):
  np.random.seed(seeds[i]) #Set random seed

  #Train test split
  X_train, X_test, y_train, y_test = tts(X, y, test_size=.1, stratify=y)

  #Define model
  model = Sequential(
    [
     keras.Input(shape=input_shape),
     Conv2D(filters=16, kernel_size=1, activation='ReLU'), #16 k=1 added
     Conv2D(filters=32, kernel_size=1, activation='ReLU'), #16 k=1
     MaxPool2D(strides=2),
     Conv2D(filters=64, kernel_size=(3,3), activation='ReLU'), #32 k=2
     Conv2D(filters=128, kernel_size=(5,5), activation='ReLU'),
     MaxPool2D(strides=2),
     Conv2D(filters=256, kernel_size=(7,7), activation='ReLU'), #64 k=3
     MaxPool2D(strides=2),
     Conv2D(filters=512, kernel_size=(7,7), activation='ReLU'),
     MaxPool2D(strides=2),
     Flatten(),
     Dense(units=64, activation='ReLU'),
     Dense(units=num_classes, activation='softmax')
    ])
  
  #Train model
  model.compile(optimizer=opt, 
                    loss="sparse_categorical_crossentropy")
  model_hist = model.fit(X_train, y_train, validation_split=.2, 
                               epochs=60, batch_size=100, verbose=2)

  #Score
  preds = np.argmax(model.predict(X_test),axis=1)
  f1 = f1_score(y_test, preds, average='weighted')
  scores.append(f1)

  #Save fold f1
  np.save('/content/gdrive/MyDrive/3. MSDS Courses/Machine Learning Time Series/MLTSA22 Project/Data/CNN_5fold_cartesianF.npy', np.array(scores))

#Save Model
model.save('/content/gdrive/MyDrive/3. MSDS Courses/Machine Learning Time Series/MLTSA22 Project/Data/CNN_CartF')
# Out:
# Epoch 1/60
# 4/4 - 2s - loss: 1.9449 - val_loss: 1.8959 - 2s/epoch - 541ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 1.8242 - val_loss: 2.0433 - 1s/epoch - 344ms/step
# Epoch 3/60
# 4/4 - 1s - loss: 1.7689 - val_loss: 1.7732 - 1s/epoch - 343ms/step
# Epoch 4/60
# 4/4 - 1s - loss: 1.6970 - val_loss: 1.7679 - 1s/epoch - 343ms/step
# Epoch 5/60
# 4/4 - 1s - loss: 1.6265 - val_loss: 1.7674 - 1s/epoch - 344ms/step
# Epoch 6/60
# 4/4 - 1s - loss: 1.6076 - val_loss: 1.6171 - 1s/epoch - 344ms/step
# Epoch 7/60
# 4/4 - 1s - loss: 1.5395 - val_loss: 1.6101 - 1s/epoch - 344ms/step
# Epoch 8/60
# 4/4 - 1s - loss: 1.4932 - val_loss: 1.5341 - 1s/epoch - 339ms/step
# Epoch 9/60
# 4/4 - 1s - loss: 1.4579 - val_loss: 1.4708 - 1s/epoch - 349ms/step
# Epoch 10/60
# 4/4 - 1s - loss: 1.4200 - val_loss: 1.5507 - 1s/epoch - 345ms/step
# Epoch 11/60
# 4/4 - 1s - loss: 1.3947 - val_loss: 1.5225 - 1s/epoch - 348ms/step
# Epoch 12/60
# 4/4 - 1s - loss: 1.3796 - val_loss: 1.4246 - 1s/epoch - 347ms/step
# Epoch 13/60
# 4/4 - 1s - loss: 1.3463 - val_loss: 1.4411 - 1s/epoch - 344ms/step
# Epoch 14/60
# 4/4 - 1s - loss: 1.2852 - val_loss: 1.3698 - 1s/epoch - 345ms/step
# Epoch 15/60
# 4/4 - 1s - loss: 1.2567 - val_loss: 1.4188 - 1s/epoch - 346ms/step
# Epoch 16/60
# 4/4 - 1s - loss: 1.2209 - val_loss: 1.3478 - 1s/epoch - 348ms/step
# Epoch 17/60
# 4/4 - 1s - loss: 1.2037 - val_loss: 1.2488 - 1s/epoch - 349ms/step
# Epoch 18/60
# 4/4 - 1s - loss: 1.1566 - val_loss: 1.3019 - 1s/epoch - 349ms/step
# Epoch 19/60
# 4/4 - 1s - loss: 1.1526 - val_loss: 1.3231 - 1s/epoch - 352ms/step
# Epoch 20/60
# 4/4 - 1s - loss: 1.1300 - val_loss: 1.1708 - 1s/epoch - 347ms/step
# Epoch 21/60
# 4/4 - 1s - loss: 1.0772 - val_loss: 1.1524 - 1s/epoch - 351ms/step
# Epoch 22/60
# 4/4 - 1s - loss: 1.0365 - val_loss: 1.1262 - 1s/epoch - 349ms/step
# Epoch 23/60
# 4/4 - 1s - loss: 1.0271 - val_loss: 1.6165 - 1s/epoch - 350ms/step
# Epoch 24/60
# 4/4 - 1s - loss: 1.1040 - val_loss: 1.1623 - 1s/epoch - 353ms/step
# Epoch 25/60
# 4/4 - 1s - loss: 1.0364 - val_loss: 1.2072 - 1s/epoch - 351ms/step
# Epoch 26/60
# 4/4 - 1s - loss: 0.9742 - val_loss: 1.0564 - 1s/epoch - 349ms/step
# Epoch 27/60
# 4/4 - 1s - loss: 0.8974 - val_loss: 1.1895 - 1s/epoch - 350ms/step
# Epoch 28/60
# 4/4 - 1s - loss: 0.8676 - val_loss: 1.0155 - 1s/epoch - 352ms/step
# Epoch 29/60
# 4/4 - 1s - loss: 0.8691 - val_loss: 1.0523 - 1s/epoch - 353ms/step
# Epoch 30/60
# 4/4 - 1s - loss: 0.7923 - val_loss: 0.9621 - 1s/epoch - 351ms/step
# Epoch 31/60
# 4/4 - 1s - loss: 0.7732 - val_loss: 0.9262 - 1s/epoch - 353ms/step
# Epoch 32/60
# 4/4 - 1s - loss: 0.7514 - val_loss: 0.9136 - 1s/epoch - 351ms/step
# Epoch 33/60
# 4/4 - 1s - loss: 0.7102 - val_loss: 0.9130 - 1s/epoch - 355ms/step
# Epoch 34/60
# 4/4 - 1s - loss: 0.6876 - val_loss: 0.8467 - 1s/epoch - 354ms/step
# Epoch 35/60
# 4/4 - 1s - loss: 0.6571 - val_loss: 0.8477 - 1s/epoch - 355ms/step
# Epoch 36/60
# 4/4 - 1s - loss: 0.6253 - val_loss: 0.8386 - 1s/epoch - 353ms/step
# Epoch 37/60
# 4/4 - 1s - loss: 0.5847 - val_loss: 0.8738 - 1s/epoch - 355ms/step
# Epoch 38/60
# 4/4 - 1s - loss: 0.5894 - val_loss: 0.8388 - 1s/epoch - 354ms/step
# Epoch 39/60
# 4/4 - 1s - loss: 0.5556 - val_loss: 0.7724 - 1s/epoch - 354ms/step
# Epoch 40/60
# 4/4 - 1s - loss: 0.5465 - val_loss: 0.8750 - 1s/epoch - 353ms/step
# Epoch 41/60
# 4/4 - 1s - loss: 0.5395 - val_loss: 0.9267 - 1s/epoch - 355ms/step
# Epoch 42/60
# 4/4 - 1s - loss: 0.5507 - val_loss: 0.7798 - 1s/epoch - 356ms/step
# Epoch 43/60
# 4/4 - 1s - loss: 0.5009 - val_loss: 0.8115 - 1s/epoch - 354ms/step
# Epoch 44/60
# 4/4 - 1s - loss: 0.4890 - val_loss: 0.7440 - 1s/epoch - 355ms/step
# Epoch 45/60
# 4/4 - 1s - loss: 0.4498 - val_loss: 0.8913 - 1s/epoch - 355ms/step
# Epoch 46/60
# 4/4 - 1s - loss: 0.5035 - val_loss: 0.7070 - 1s/epoch - 357ms/step
# Epoch 47/60
# 4/4 - 1s - loss: 0.4358 - val_loss: 0.7090 - 1s/epoch - 356ms/step
# Epoch 48/60
# 4/4 - 1s - loss: 0.4106 - val_loss: 0.8673 - 1s/epoch - 356ms/step
# Epoch 49/60
# 4/4 - 1s - loss: 0.4563 - val_loss: 0.7113 - 1s/epoch - 357ms/step
# Epoch 50/60
# 4/4 - 1s - loss: 0.4107 - val_loss: 0.6762 - 1s/epoch - 356ms/step
# Epoch 51/60
# 4/4 - 1s - loss: 0.4034 - val_loss: 0.7680 - 1s/epoch - 358ms/step
# Epoch 52/60
# 4/4 - 1s - loss: 0.3784 - val_loss: 0.6692 - 1s/epoch - 358ms/step
# Epoch 53/60
# 4/4 - 1s - loss: 0.3339 - val_loss: 0.7074 - 1s/epoch - 358ms/step
# Epoch 54/60
# 4/4 - 1s - loss: 0.3301 - val_loss: 0.7360 - 1s/epoch - 359ms/step
# Epoch 55/60
# 4/4 - 1s - loss: 0.3555 - val_loss: 0.9039 - 1s/epoch - 358ms/step
# Epoch 56/60
# 4/4 - 1s - loss: 0.3577 - val_loss: 0.6454 - 1s/epoch - 359ms/step
# Epoch 57/60
# 4/4 - 1s - loss: 0.3366 - val_loss: 0.6626 - 1s/epoch - 359ms/step
# Epoch 58/60
# 4/4 - 1s - loss: 0.2765 - val_loss: 0.7885 - 1s/epoch - 359ms/step
# Epoch 59/60
# 4/4 - 1s - loss: 0.2715 - val_loss: 0.6602 - 1s/epoch - 359ms/step
# Epoch 60/60
# 4/4 - 1s - loss: 0.2701 - val_loss: 0.7486 - 1s/epoch - 357ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f13b27c8200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f13b27c8200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/60
# 4/4 - 2s - loss: 1.9548 - val_loss: 1.9437 - 2s/epoch - 543ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 1.9455 - val_loss: 1.9507 - 1s/epoch - 359ms/step
# Epoch 3/60
# 4/4 - 2s - loss: 1.9461 - val_loss: 1.9358 - 2s/epoch - 378ms/step
# Epoch 4/60
# 4/4 - 1s - loss: 1.9239 - val_loss: 1.8882 - 1s/epoch - 353ms/step
# Epoch 5/60
# 4/4 - 1s - loss: 1.8232 - val_loss: 1.6798 - 1s/epoch - 355ms/step
# Epoch 6/60
# 4/4 - 1s - loss: 1.6897 - val_loss: 1.6455 - 1s/epoch - 358ms/step
# Epoch 7/60
# 4/4 - 1s - loss: 1.6006 - val_loss: 1.6680 - 1s/epoch - 356ms/step
# Epoch 8/60
# 4/4 - 1s - loss: 1.5516 - val_loss: 1.5400 - 1s/epoch - 355ms/step
# Epoch 9/60
# 4/4 - 1s - loss: 1.5050 - val_loss: 1.4485 - 1s/epoch - 355ms/step
# Epoch 10/60
# 4/4 - 1s - loss: 1.4596 - val_loss: 1.4702 - 1s/epoch - 355ms/step
# Epoch 11/60
# 4/4 - 1s - loss: 1.4379 - val_loss: 1.4017 - 1s/epoch - 357ms/step
# Epoch 12/60
# 4/4 - 1s - loss: 1.4007 - val_loss: 1.4605 - 1s/epoch - 353ms/step
# Epoch 13/60
# 4/4 - 1s - loss: 1.3946 - val_loss: 1.3756 - 1s/epoch - 353ms/step
# Epoch 14/60
# 4/4 - 1s - loss: 1.3743 - val_loss: 1.3570 - 1s/epoch - 355ms/step
# Epoch 15/60
# 4/4 - 1s - loss: 1.3349 - val_loss: 1.3264 - 1s/epoch - 355ms/step
# Epoch 16/60
# 4/4 - 1s - loss: 1.3130 - val_loss: 1.2219 - 1s/epoch - 367ms/step
# Epoch 17/60
# 4/4 - 1s - loss: 1.2840 - val_loss: 1.3807 - 1s/epoch - 356ms/step
# Epoch 18/60
# 4/4 - 1s - loss: 1.2700 - val_loss: 1.2538 - 1s/epoch - 355ms/step
# Epoch 19/60
# 4/4 - 1s - loss: 1.2399 - val_loss: 1.2693 - 1s/epoch - 355ms/step
# Epoch 20/60
# 4/4 - 1s - loss: 1.1738 - val_loss: 1.2215 - 1s/epoch - 355ms/step
# Epoch 21/60
# 4/4 - 1s - loss: 1.1876 - val_loss: 1.1735 - 1s/epoch - 368ms/step
# Epoch 22/60
# 4/4 - 1s - loss: 1.1330 - val_loss: 1.1456 - 1s/epoch - 363ms/step
# Epoch 23/60
# 4/4 - 1s - loss: 1.0789 - val_loss: 1.0646 - 1s/epoch - 355ms/step
# Epoch 24/60
# 4/4 - 1s - loss: 1.0568 - val_loss: 1.1082 - 1s/epoch - 358ms/step
# Epoch 25/60
# 4/4 - 1s - loss: 1.0358 - val_loss: 1.1966 - 1s/epoch - 356ms/step
# Epoch 26/60
# 4/4 - 1s - loss: 1.0896 - val_loss: 1.3357 - 1s/epoch - 355ms/step
# Epoch 27/60
# 4/4 - 1s - loss: 1.0788 - val_loss: 1.1995 - 1s/epoch - 357ms/step
# Epoch 28/60
# 4/4 - 1s - loss: 1.0040 - val_loss: 1.0966 - 1s/epoch - 357ms/step
# Epoch 29/60
# 4/4 - 1s - loss: 1.0435 - val_loss: 1.1045 - 1s/epoch - 355ms/step
# Epoch 30/60
# 4/4 - 1s - loss: 0.9630 - val_loss: 1.0860 - 1s/epoch - 355ms/step
# Epoch 31/60
# 4/4 - 1s - loss: 0.9349 - val_loss: 1.0172 - 1s/epoch - 355ms/step
# Epoch 32/60
# 4/4 - 1s - loss: 0.8783 - val_loss: 1.0706 - 1s/epoch - 355ms/step
# Epoch 33/60
# 4/4 - 1s - loss: 0.8347 - val_loss: 0.9953 - 1s/epoch - 354ms/step
# Epoch 34/60
# 4/4 - 1s - loss: 0.8233 - val_loss: 1.0488 - 1s/epoch - 355ms/step
# Epoch 35/60
# 4/4 - 1s - loss: 0.8028 - val_loss: 1.0155 - 1s/epoch - 354ms/step
# Epoch 36/60
# 4/4 - 1s - loss: 0.7536 - val_loss: 1.0868 - 1s/epoch - 367ms/step
# Epoch 37/60
# 4/4 - 1s - loss: 0.7464 - val_loss: 1.0723 - 1s/epoch - 355ms/step
# Epoch 38/60
# 4/4 - 1s - loss: 0.7468 - val_loss: 1.0446 - 1s/epoch - 354ms/step
# Epoch 39/60
# 4/4 - 1s - loss: 0.6994 - val_loss: 1.0598 - 1s/epoch - 357ms/step
# Epoch 40/60
# 4/4 - 1s - loss: 0.6880 - val_loss: 1.1269 - 1s/epoch - 354ms/step
# Epoch 41/60
# 4/4 - 1s - loss: 0.7005 - val_loss: 1.1743 - 1s/epoch - 354ms/step
# Epoch 42/60
# 4/4 - 1s - loss: 0.8105 - val_loss: 1.3163 - 1s/epoch - 354ms/step
# Epoch 43/60
# 4/4 - 1s - loss: 0.7535 - val_loss: 1.5427 - 1s/epoch - 354ms/step
# Epoch 44/60
# 4/4 - 1s - loss: 0.7679 - val_loss: 1.1838 - 1s/epoch - 355ms/step
# Epoch 45/60
# 4/4 - 1s - loss: 0.7097 - val_loss: 1.0685 - 1s/epoch - 355ms/step
# Epoch 46/60
# 4/4 - 1s - loss: 0.6691 - val_loss: 1.0816 - 1s/epoch - 355ms/step
# Epoch 47/60
# 4/4 - 1s - loss: 0.6493 - val_loss: 1.0637 - 1s/epoch - 354ms/step
# Epoch 48/60
# 4/4 - 1s - loss: 0.6209 - val_loss: 1.0067 - 1s/epoch - 355ms/step
# Epoch 49/60
# 4/4 - 1s - loss: 0.5666 - val_loss: 1.0728 - 1s/epoch - 359ms/step
# Epoch 50/60
# 4/4 - 1s - loss: 0.5598 - val_loss: 1.0345 - 1s/epoch - 355ms/step
# Epoch 51/60
# 4/4 - 1s - loss: 0.5539 - val_loss: 1.1757 - 1s/epoch - 356ms/step
# Epoch 52/60
# 4/4 - 1s - loss: 0.5631 - val_loss: 1.0791 - 1s/epoch - 356ms/step
# Epoch 53/60
# 4/4 - 1s - loss: 0.5081 - val_loss: 1.1737 - 1s/epoch - 354ms/step
# Epoch 54/60
# 4/4 - 1s - loss: 0.5958 - val_loss: 1.1779 - 1s/epoch - 354ms/step
# Epoch 55/60
# 4/4 - 1s - loss: 0.5379 - val_loss: 1.0990 - 1s/epoch - 368ms/step
# Epoch 56/60
# 4/4 - 1s - loss: 0.4874 - val_loss: 1.1913 - 1s/epoch - 355ms/step
# Epoch 57/60
# 4/4 - 1s - loss: 0.5040 - val_loss: 1.1534 - 1s/epoch - 357ms/step
# Epoch 58/60
# 4/4 - 1s - loss: 0.4802 - val_loss: 1.0844 - 1s/epoch - 356ms/step
# Epoch 59/60
# 4/4 - 1s - loss: 0.4685 - val_loss: 1.1840 - 1s/epoch - 355ms/step
# Epoch 60/60
# 4/4 - 1s - loss: 0.4400 - val_loss: 1.1269 - 1s/epoch - 352ms/step
# Epoch 1/60
# 4/4 - 2s - loss: 1.9542 - val_loss: 1.8585 - 2s/epoch - 542ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 1.8461 - val_loss: 1.5600 - 1s/epoch - 361ms/step
# Epoch 3/60
# 4/4 - 1s - loss: 1.7764 - val_loss: 1.7474 - 1s/epoch - 359ms/step
# Epoch 4/60
# 4/4 - 1s - loss: 1.7586 - val_loss: 1.6062 - 1s/epoch - 361ms/step
# Epoch 5/60
# 4/4 - 1s - loss: 1.6783 - val_loss: 1.5022 - 1s/epoch - 358ms/step
# Epoch 6/60
# 4/4 - 1s - loss: 1.6807 - val_loss: 1.6146 - 1s/epoch - 356ms/step
# Epoch 7/60
# 4/4 - 1s - loss: 1.6058 - val_loss: 1.4241 - 1s/epoch - 357ms/step
# Epoch 8/60
# 4/4 - 1s - loss: 1.4874 - val_loss: 1.4060 - 1s/epoch - 358ms/step
# Epoch 9/60
# 4/4 - 1s - loss: 1.4073 - val_loss: 1.3231 - 1s/epoch - 360ms/step
# Epoch 10/60
# 4/4 - 1s - loss: 1.4583 - val_loss: 1.3967 - 1s/epoch - 358ms/step
# Epoch 11/60
# 4/4 - 1s - loss: 1.4644 - val_loss: 1.3897 - 1s/epoch - 359ms/step
# Epoch 12/60
# 4/4 - 1s - loss: 1.3891 - val_loss: 1.2079 - 1s/epoch - 359ms/step
# Epoch 13/60
# 4/4 - 1s - loss: 1.3108 - val_loss: 1.2147 - 1s/epoch - 372ms/step
# Epoch 14/60
# 4/4 - 1s - loss: 1.2533 - val_loss: 1.2980 - 1s/epoch - 357ms/step
# Epoch 15/60
# 4/4 - 1s - loss: 1.1679 - val_loss: 1.1426 - 1s/epoch - 360ms/step
# Epoch 16/60
# 4/4 - 1s - loss: 1.1570 - val_loss: 1.0789 - 1s/epoch - 371ms/step
# Epoch 17/60
# 4/4 - 1s - loss: 1.0883 - val_loss: 1.2910 - 1s/epoch - 361ms/step
# Epoch 18/60
# 4/4 - 1s - loss: 1.1029 - val_loss: 1.0050 - 1s/epoch - 372ms/step
# Epoch 19/60
# 4/4 - 1s - loss: 1.0848 - val_loss: 1.1857 - 1s/epoch - 360ms/step
# Epoch 20/60
# 4/4 - 1s - loss: 1.0254 - val_loss: 1.0715 - 1s/epoch - 360ms/step
# Epoch 21/60
# 4/4 - 1s - loss: 1.0410 - val_loss: 0.9736 - 1s/epoch - 360ms/step
# Epoch 22/60
# 4/4 - 1s - loss: 0.9643 - val_loss: 0.9210 - 1s/epoch - 362ms/step
# Epoch 23/60
# 4/4 - 1s - loss: 0.9603 - val_loss: 0.9764 - 1s/epoch - 360ms/step
# Epoch 24/60
# 4/4 - 1s - loss: 0.9170 - val_loss: 1.0530 - 1s/epoch - 361ms/step
# Epoch 25/60
# 4/4 - 1s - loss: 0.8845 - val_loss: 0.8709 - 1s/epoch - 359ms/step
# Epoch 26/60
# 4/4 - 1s - loss: 0.8514 - val_loss: 0.9482 - 1s/epoch - 361ms/step
# Epoch 27/60
# 4/4 - 1s - loss: 0.8258 - val_loss: 0.9486 - 1s/epoch - 373ms/step
# Epoch 28/60
# 4/4 - 1s - loss: 0.8479 - val_loss: 0.9261 - 1s/epoch - 361ms/step
# Epoch 29/60
# 4/4 - 1s - loss: 0.8501 - val_loss: 0.8858 - 1s/epoch - 361ms/step
# Epoch 30/60
# 4/4 - 1s - loss: 0.7543 - val_loss: 0.9121 - 1s/epoch - 373ms/step
# Epoch 31/60
# 4/4 - 1s - loss: 0.7616 - val_loss: 0.8296 - 1s/epoch - 361ms/step
# Epoch 32/60
# 4/4 - 1s - loss: 0.7432 - val_loss: 0.8273 - 1s/epoch - 361ms/step
# Epoch 33/60
# 4/4 - 1s - loss: 0.6930 - val_loss: 0.9934 - 1s/epoch - 374ms/step
# Epoch 34/60
# 4/4 - 1s - loss: 0.7590 - val_loss: 0.8406 - 1s/epoch - 361ms/step
# Epoch 35/60
# 4/4 - 1s - loss: 0.7225 - val_loss: 1.0535 - 1s/epoch - 360ms/step
# Epoch 36/60
# 4/4 - 1s - loss: 0.7660 - val_loss: 1.1227 - 1s/epoch - 361ms/step
# Epoch 37/60
# 4/4 - 1s - loss: 0.8054 - val_loss: 0.7874 - 1s/epoch - 361ms/step
# Epoch 38/60
# 4/4 - 1s - loss: 0.7163 - val_loss: 0.9866 - 1s/epoch - 359ms/step
# Epoch 39/60
# 4/4 - 1s - loss: 0.6569 - val_loss: 0.7697 - 1s/epoch - 374ms/step
# Epoch 40/60
# 4/4 - 1s - loss: 0.6611 - val_loss: 0.8952 - 1s/epoch - 362ms/step
# Epoch 41/60
# 4/4 - 1s - loss: 0.5889 - val_loss: 0.8331 - 1s/epoch - 359ms/step
# Epoch 42/60
# 4/4 - 1s - loss: 0.5236 - val_loss: 0.6769 - 1s/epoch - 362ms/step
# Epoch 43/60
# 4/4 - 1s - loss: 0.4804 - val_loss: 0.8482 - 1s/epoch - 361ms/step
# Epoch 44/60
# 4/4 - 1s - loss: 0.4478 - val_loss: 0.6890 - 1s/epoch - 361ms/step
# Epoch 45/60
# 4/4 - 1s - loss: 0.4252 - val_loss: 0.7640 - 1s/epoch - 361ms/step
# Epoch 46/60
# 4/4 - 1s - loss: 0.3939 - val_loss: 0.6432 - 1s/epoch - 363ms/step
# Epoch 47/60
# 4/4 - 1s - loss: 0.3862 - val_loss: 0.6327 - 1s/epoch - 361ms/step
# Epoch 48/60
# 4/4 - 1s - loss: 0.3261 - val_loss: 0.7739 - 1s/epoch - 362ms/step
# Epoch 49/60
# 4/4 - 1s - loss: 0.3048 - val_loss: 0.7133 - 1s/epoch - 375ms/step
# Epoch 50/60
# 4/4 - 1s - loss: 0.2849 - val_loss: 0.7652 - 1s/epoch - 361ms/step
# Epoch 51/60
# 4/4 - 1s - loss: 0.2993 - val_loss: 0.6271 - 1s/epoch - 362ms/step
# Epoch 52/60
# 4/4 - 1s - loss: 0.2737 - val_loss: 0.7662 - 1s/epoch - 362ms/step
# Epoch 53/60
# 4/4 - 1s - loss: 0.2784 - val_loss: 0.8213 - 1s/epoch - 362ms/step
# Epoch 54/60
# 4/4 - 1s - loss: 0.3119 - val_loss: 0.7016 - 1s/epoch - 361ms/step
# Epoch 55/60
# 4/4 - 1s - loss: 0.2590 - val_loss: 0.8658 - 1s/epoch - 361ms/step
# Epoch 56/60
# 4/4 - 1s - loss: 0.2813 - val_loss: 0.7712 - 1s/epoch - 360ms/step
# Epoch 57/60
# 4/4 - 1s - loss: 0.3691 - val_loss: 0.9584 - 1s/epoch - 362ms/step
# Epoch 58/60
# 4/4 - 1s - loss: 0.4819 - val_loss: 0.7301 - 1s/epoch - 362ms/step
# Epoch 59/60
# 4/4 - 1s - loss: 0.3802 - val_loss: 0.6347 - 1s/epoch - 362ms/step
# Epoch 60/60
# 4/4 - 1s - loss: 0.3083 - val_loss: 0.9583 - 1s/epoch - 359ms/step
# Epoch 1/60
# 4/4 - 2s - loss: 1.9481 - val_loss: 1.9548 - 2s/epoch - 530ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 1.9639 - val_loss: 1.9447 - 1s/epoch - 361ms/step
# Epoch 3/60
# 4/4 - 1s - loss: 1.9401 - val_loss: 1.9339 - 1s/epoch - 359ms/step
# Epoch 4/60
# 4/4 - 1s - loss: 1.9538 - val_loss: 1.9318 - 1s/epoch - 368ms/step
# Epoch 5/60
# 4/4 - 1s - loss: 1.9233 - val_loss: 1.8779 - 1s/epoch - 357ms/step
# Epoch 6/60
# 4/4 - 1s - loss: 1.8468 - val_loss: 1.7648 - 1s/epoch - 355ms/step
# Epoch 7/60
# 4/4 - 1s - loss: 1.6988 - val_loss: 1.6598 - 1s/epoch - 356ms/step
# Epoch 8/60
# 4/4 - 1s - loss: 1.6839 - val_loss: 1.6019 - 1s/epoch - 357ms/step
# Epoch 9/60
# 4/4 - 1s - loss: 1.5789 - val_loss: 1.5108 - 1s/epoch - 357ms/step
# Epoch 10/60
# 4/4 - 1s - loss: 1.5231 - val_loss: 1.4833 - 1s/epoch - 357ms/step
# Epoch 11/60
# 4/4 - 1s - loss: 1.4851 - val_loss: 1.4500 - 1s/epoch - 356ms/step
# Epoch 12/60
# 4/4 - 1s - loss: 1.5142 - val_loss: 1.4959 - 1s/epoch - 357ms/step
# Epoch 13/60
# 4/4 - 1s - loss: 1.4543 - val_loss: 1.4295 - 1s/epoch - 356ms/step
# Epoch 14/60
# 4/4 - 1s - loss: 1.4083 - val_loss: 1.4231 - 1s/epoch - 357ms/step
# Epoch 15/60
# 4/4 - 1s - loss: 1.3870 - val_loss: 1.4333 - 1s/epoch - 358ms/step
# Epoch 16/60
# 4/4 - 1s - loss: 1.4078 - val_loss: 1.3739 - 1s/epoch - 359ms/step
# Epoch 17/60
# 4/4 - 1s - loss: 1.4267 - val_loss: 1.4824 - 1s/epoch - 359ms/step
# Epoch 18/60
# 4/4 - 1s - loss: 1.4634 - val_loss: 1.4021 - 1s/epoch - 358ms/step
# Epoch 19/60
# 4/4 - 1s - loss: 1.3396 - val_loss: 1.3567 - 1s/epoch - 356ms/step
# Epoch 20/60
# 4/4 - 1s - loss: 1.2998 - val_loss: 1.3161 - 1s/epoch - 358ms/step
# Epoch 21/60
# 4/4 - 1s - loss: 1.2644 - val_loss: 1.3349 - 1s/epoch - 357ms/step
# Epoch 22/60
# 4/4 - 1s - loss: 1.2577 - val_loss: 1.2762 - 1s/epoch - 358ms/step
# Epoch 23/60
# 4/4 - 1s - loss: 1.2080 - val_loss: 1.2613 - 1s/epoch - 358ms/step
# Epoch 24/60
# 4/4 - 1s - loss: 1.2296 - val_loss: 1.2358 - 1s/epoch - 357ms/step
# Epoch 25/60
# 4/4 - 1s - loss: 1.1628 - val_loss: 1.2444 - 1s/epoch - 358ms/step
# Epoch 26/60
# 4/4 - 1s - loss: 1.0948 - val_loss: 1.2049 - 1s/epoch - 358ms/step
# Epoch 27/60
# 4/4 - 1s - loss: 1.0892 - val_loss: 1.1901 - 1s/epoch - 357ms/step
# Epoch 28/60
# 4/4 - 1s - loss: 1.0515 - val_loss: 1.1501 - 1s/epoch - 359ms/step
# Epoch 29/60
# 4/4 - 1s - loss: 1.0198 - val_loss: 1.1422 - 1s/epoch - 359ms/step
# Epoch 30/60
# 4/4 - 1s - loss: 0.9967 - val_loss: 1.1141 - 1s/epoch - 360ms/step
# Epoch 31/60
# 4/4 - 1s - loss: 0.9640 - val_loss: 1.0794 - 1s/epoch - 359ms/step
# Epoch 32/60
# 4/4 - 1s - loss: 0.9369 - val_loss: 1.2969 - 1s/epoch - 360ms/step
# Epoch 33/60
# 4/4 - 1s - loss: 0.9804 - val_loss: 1.0595 - 1s/epoch - 359ms/step
# Epoch 34/60
# 4/4 - 1s - loss: 0.9303 - val_loss: 1.0603 - 1s/epoch - 360ms/step
# Epoch 35/60
# 4/4 - 1s - loss: 0.8899 - val_loss: 1.1188 - 1s/epoch - 357ms/step
# Epoch 36/60
# 4/4 - 1s - loss: 0.8845 - val_loss: 1.0040 - 1s/epoch - 357ms/step
# Epoch 37/60
# 4/4 - 1s - loss: 0.8129 - val_loss: 0.9945 - 1s/epoch - 362ms/step
# Epoch 38/60
# 4/4 - 1s - loss: 0.7681 - val_loss: 1.1043 - 1s/epoch - 358ms/step
# Epoch 39/60
# 4/4 - 1s - loss: 0.7852 - val_loss: 0.9452 - 1s/epoch - 359ms/step
# Epoch 40/60
# 4/4 - 1s - loss: 0.7497 - val_loss: 0.9997 - 1s/epoch - 359ms/step
# Epoch 41/60
# 4/4 - 1s - loss: 0.7755 - val_loss: 1.0866 - 1s/epoch - 359ms/step
# Epoch 42/60
# 4/4 - 1s - loss: 0.7718 - val_loss: 0.9628 - 1s/epoch - 360ms/step
# Epoch 43/60
# 4/4 - 1s - loss: 0.6956 - val_loss: 0.9153 - 1s/epoch - 358ms/step
# Epoch 44/60
# 4/4 - 1s - loss: 0.6679 - val_loss: 0.9506 - 1s/epoch - 360ms/step
# Epoch 45/60
# 4/4 - 1s - loss: 0.6937 - val_loss: 0.9532 - 1s/epoch - 358ms/step
# Epoch 46/60
# 4/4 - 1s - loss: 0.6698 - val_loss: 1.1242 - 1s/epoch - 359ms/step
# Epoch 47/60
# 4/4 - 1s - loss: 0.6963 - val_loss: 0.9849 - 1s/epoch - 358ms/step
# Epoch 48/60
# 4/4 - 1s - loss: 0.6679 - val_loss: 1.0634 - 1s/epoch - 358ms/step
# Epoch 49/60
# 4/4 - 1s - loss: 0.6479 - val_loss: 0.9009 - 1s/epoch - 359ms/step
# Epoch 50/60
# 4/4 - 1s - loss: 0.6640 - val_loss: 0.8854 - 1s/epoch - 359ms/step
# Epoch 51/60
# 4/4 - 1s - loss: 0.5624 - val_loss: 0.9522 - 1s/epoch - 359ms/step
# Epoch 52/60
# 4/4 - 1s - loss: 0.5585 - val_loss: 0.9103 - 1s/epoch - 358ms/step
# Epoch 53/60
# 4/4 - 1s - loss: 0.5527 - val_loss: 1.0416 - 1s/epoch - 358ms/step
# Epoch 54/60
# 4/4 - 1s - loss: 0.5665 - val_loss: 0.8175 - 1s/epoch - 359ms/step
# Epoch 55/60
# 4/4 - 1s - loss: 0.5185 - val_loss: 0.8619 - 1s/epoch - 360ms/step
# Epoch 56/60
# 4/4 - 1s - loss: 0.4689 - val_loss: 0.8809 - 1s/epoch - 360ms/step
# Epoch 57/60
# 4/4 - 1s - loss: 0.4745 - val_loss: 0.8381 - 1s/epoch - 358ms/step
# Epoch 58/60
# 4/4 - 1s - loss: 0.4381 - val_loss: 0.8495 - 1s/epoch - 359ms/step
# Epoch 59/60
# 4/4 - 1s - loss: 0.4315 - val_loss: 0.8336 - 1s/epoch - 358ms/step
# Epoch 60/60
# 4/4 - 1s - loss: 0.4308 - val_loss: 0.8282 - 1s/epoch - 357ms/step
# Epoch 1/60
# 4/4 - 2s - loss: 1.9446 - val_loss: 1.9028 - 2s/epoch - 532ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 1.8337 - val_loss: 1.8307 - 1s/epoch - 359ms/step
# Epoch 3/60
# 4/4 - 1s - loss: 1.7305 - val_loss: 1.8269 - 1s/epoch - 362ms/step
# Epoch 4/60
# 4/4 - 1s - loss: 1.6349 - val_loss: 1.6601 - 1s/epoch - 358ms/step
# Epoch 5/60
# 4/4 - 1s - loss: 1.5310 - val_loss: 1.5451 - 1s/epoch - 358ms/step
# Epoch 6/60
# 4/4 - 1s - loss: 1.5363 - val_loss: 1.9177 - 1s/epoch - 359ms/step
# Epoch 7/60
# 4/4 - 1s - loss: 1.5318 - val_loss: 1.5511 - 1s/epoch - 360ms/step
# Epoch 8/60
# 4/4 - 1s - loss: 1.4609 - val_loss: 1.5732 - 1s/epoch - 358ms/step
# Epoch 9/60
# 4/4 - 1s - loss: 1.4040 - val_loss: 1.5923 - 1s/epoch - 356ms/step
# Epoch 10/60
# 4/4 - 1s - loss: 1.3609 - val_loss: 1.5151 - 1s/epoch - 358ms/step
# Epoch 11/60
# 4/4 - 1s - loss: 1.3108 - val_loss: 1.5400 - 1s/epoch - 359ms/step
# Epoch 12/60
# 4/4 - 1s - loss: 1.3199 - val_loss: 1.4444 - 1s/epoch - 359ms/step
# Epoch 13/60
# 4/4 - 1s - loss: 1.2257 - val_loss: 1.4192 - 1s/epoch - 358ms/step
# Epoch 14/60
# 4/4 - 1s - loss: 1.1940 - val_loss: 1.5529 - 1s/epoch - 359ms/step
# Epoch 15/60
# 4/4 - 1s - loss: 1.1671 - val_loss: 2.0140 - 1s/epoch - 359ms/step
# Epoch 16/60
# 4/4 - 1s - loss: 1.3436 - val_loss: 1.5969 - 1s/epoch - 358ms/step
# Epoch 17/60
# 4/4 - 1s - loss: 1.2212 - val_loss: 1.3459 - 1s/epoch - 359ms/step
# Epoch 18/60
# 4/4 - 1s - loss: 1.2191 - val_loss: 1.4208 - 1s/epoch - 359ms/step
# Epoch 19/60
# 4/4 - 1s - loss: 1.1748 - val_loss: 1.4265 - 1s/epoch - 358ms/step
# Epoch 20/60
# 4/4 - 1s - loss: 1.1240 - val_loss: 1.3467 - 1s/epoch - 359ms/step
# Epoch 21/60
# 4/4 - 1s - loss: 1.0939 - val_loss: 1.3178 - 1s/epoch - 359ms/step
# Epoch 22/60
# 4/4 - 1s - loss: 1.0360 - val_loss: 1.3810 - 1s/epoch - 357ms/step
# Epoch 23/60
# 4/4 - 1s - loss: 1.0060 - val_loss: 1.2801 - 1s/epoch - 359ms/step
# Epoch 24/60
# 4/4 - 1s - loss: 0.9843 - val_loss: 1.4054 - 1s/epoch - 360ms/step
# Epoch 25/60
# 4/4 - 1s - loss: 0.9648 - val_loss: 1.5245 - 1s/epoch - 359ms/step
# Epoch 26/60
# 4/4 - 1s - loss: 0.9685 - val_loss: 1.4339 - 1s/epoch - 358ms/step
# Epoch 27/60
# 4/4 - 1s - loss: 0.9585 - val_loss: 1.4945 - 1s/epoch - 359ms/step
# Epoch 28/60
# 4/4 - 1s - loss: 0.9530 - val_loss: 1.1611 - 1s/epoch - 359ms/step
# Epoch 29/60
# 4/4 - 1s - loss: 0.8801 - val_loss: 1.2338 - 1s/epoch - 360ms/step
# Epoch 30/60
# 4/4 - 1s - loss: 0.8558 - val_loss: 1.3105 - 1s/epoch - 358ms/step
# Epoch 31/60
# 4/4 - 1s - loss: 0.8069 - val_loss: 1.1629 - 1s/epoch - 359ms/step
# Epoch 32/60
# 4/4 - 1s - loss: 0.7778 - val_loss: 1.2893 - 1s/epoch - 359ms/step
# Epoch 33/60
# 4/4 - 1s - loss: 0.7715 - val_loss: 1.2109 - 1s/epoch - 359ms/step
# Epoch 34/60
# 4/4 - 1s - loss: 0.7185 - val_loss: 1.1431 - 1s/epoch - 361ms/step
# Epoch 35/60
# 4/4 - 1s - loss: 0.6832 - val_loss: 1.4285 - 1s/epoch - 359ms/step
# Epoch 36/60
# 4/4 - 1s - loss: 0.7188 - val_loss: 1.3635 - 1s/epoch - 359ms/step
# Epoch 37/60
# 4/4 - 1s - loss: 0.6972 - val_loss: 1.2174 - 1s/epoch - 358ms/step
# Epoch 38/60
# 4/4 - 1s - loss: 0.5773 - val_loss: 1.1907 - 1s/epoch - 360ms/step
# Epoch 39/60
# 4/4 - 1s - loss: 0.6314 - val_loss: 1.2134 - 1s/epoch - 361ms/step
# Epoch 40/60
# 4/4 - 1s - loss: 0.5679 - val_loss: 1.3626 - 1s/epoch - 359ms/step
# Epoch 41/60
# 4/4 - 1s - loss: 0.5614 - val_loss: 1.2983 - 1s/epoch - 360ms/step
# Epoch 42/60
# 4/4 - 1s - loss: 0.5509 - val_loss: 1.2281 - 1s/epoch - 359ms/step
# Epoch 43/60
# 4/4 - 1s - loss: 0.5383 - val_loss: 1.4628 - 1s/epoch - 359ms/step
# Epoch 44/60
# 4/4 - 1s - loss: 0.5993 - val_loss: 1.3330 - 1s/epoch - 361ms/step
# Epoch 45/60
# 4/4 - 1s - loss: 0.5316 - val_loss: 1.3020 - 1s/epoch - 360ms/step
# Epoch 46/60
# 4/4 - 1s - loss: 0.5917 - val_loss: 1.1353 - 1s/epoch - 361ms/step
# Epoch 47/60
# 4/4 - 1s - loss: 0.5103 - val_loss: 1.1735 - 1s/epoch - 361ms/step
# Epoch 48/60
# 4/4 - 1s - loss: 0.4925 - val_loss: 1.2256 - 1s/epoch - 359ms/step
# Epoch 49/60
# 4/4 - 1s - loss: 0.4624 - val_loss: 1.1776 - 1s/epoch - 358ms/step
# Epoch 50/60
# 4/4 - 1s - loss: 0.4512 - val_loss: 1.3260 - 1s/epoch - 359ms/step
# Epoch 51/60
# 4/4 - 1s - loss: 0.4154 - val_loss: 1.3037 - 1s/epoch - 360ms/step
# Epoch 52/60
# 4/4 - 1s - loss: 0.3833 - val_loss: 1.4419 - 1s/epoch - 359ms/step
# Epoch 53/60
# 4/4 - 1s - loss: 0.4299 - val_loss: 1.2504 - 1s/epoch - 359ms/step
# Epoch 54/60
# 4/4 - 1s - loss: 0.4494 - val_loss: 1.2686 - 1s/epoch - 361ms/step
# Epoch 55/60
# 4/4 - 1s - loss: 0.4061 - val_loss: 1.3533 - 1s/epoch - 360ms/step
# Epoch 56/60
# 4/4 - 1s - loss: 0.3828 - val_loss: 1.2238 - 1s/epoch - 358ms/step
# Epoch 57/60
# 4/4 - 1s - loss: 0.3259 - val_loss: 1.3706 - 1s/epoch - 360ms/step
# Epoch 58/60
# 4/4 - 1s - loss: 0.3360 - val_loss: 1.4222 - 1s/epoch - 361ms/step
# Epoch 59/60
# 4/4 - 1s - loss: 0.3566 - val_loss: 1.3528 - 1s/epoch - 360ms/step
# Epoch 60/60
# 4/4 - 1s - loss: 0.2920 - val_loss: 1.5834 - 1s/epoch - 358ms/step
# WARNING:absl:Found untraced functions such as re_lu_63_layer_call_fn, re_lu_63_layer_call_and_return_conditional_losses, re_lu_64_layer_call_fn, re_lu_64_layer_call_and_return_conditional_losses, re_lu_65_layer_call_fn while saving (showing 5 of 14). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/3. MSDS Courses/Machine Learning Time Series/MLTSA22 Project/Data/CNN_CartF/assets
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/3. MSDS Courses/Machine Learning Time Series/MLTSA22 Project/Data/CNN_CartF/assets

# %%
#Plot Training and Validation Loss of last run
plt.figure(figsize=(10,8))
plt.title('CNN_Cart')
plt.plot(model_hist.history['loss'], label='Training')
plt.plot(model_hist.history['val_loss'], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Categorical Crossentropy');
